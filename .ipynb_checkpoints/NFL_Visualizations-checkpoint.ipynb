# %% [markdown]
# # NFL Data Cleaning
# ### Discovery and Cleaning of Raw Dataset for Further Analysis

# %%
#importing dependancies
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
#import raw data for discovery and cleaning using pandas
df = pd.read_csv(r'raw_data\spreadspoke_scores.csv')

# %%
#verify data loaded in correctly
df.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0      9/2/1966             1966             1             False
# 1      9/3/1966             1966             1             False
# 2      9/4/1966             1966             1             False
# 3      9/9/1966             1966             2             False
# 4     9/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      Miami Dolphins        14.0        23.0  Oakland Raiders
# 1      Houston Oilers        45.0         7.0   Denver Broncos
# 2  San Diego Chargers        27.0         7.0    Buffalo Bills
# 3      Miami Dolphins        14.0        19.0    New York Jets
# 4   Green Bay Packers        24.0         3.0  Baltimore Colts
#
#   team_favorite_id  spread_favorite over_under_line         stadium  \
# 0              NaN              NaN             NaN     Orange Bowl
# 1              NaN              NaN             NaN    Rice Stadium
# 2              NaN              NaN             NaN  Balboa Stadium
# 3              NaN              NaN             NaN     Orange Bowl
# 4              NaN              NaN             NaN   Lambeau Field
#
#    stadium_neutral  weather_temperature  weather_wind_mph  weather_humidity  \
# 0            False                 83.0               6.0              71.0
# 1            False                 81.0               7.0              70.0
# 2            False                 70.0               7.0              82.0
# 3            False                 82.0              11.0              78.0
# 4            False                 64.0               8.0              62.0
#
#   weather_detail
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# explore size and shape of DataFrame, look for number of columns 
df.size
# Out:
# 239241

# %%
#Column names
df.columns
# Out:
# Index(['schedule_date', 'schedule_season', 'schedule_week', 'schedule_playoff',
#        'team_home', 'score_home', 'score_away', 'team_away',
#        'team_favorite_id', 'spread_favorite', 'over_under_line', 'stadium',
#        'stadium_neutral', 'weather_temperature', 'weather_wind_mph',
#        'weather_humidity', 'weather_detail'],
#       dtype='object')

# %%
#Look for column names and datatypes, see if any adjustments should be made to datatypes. 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14073 entries, 0 to 14072
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   schedule_date        14073 non-null  object
#  1   schedule_season      14073 non-null  int64
#  2   schedule_week        14073 non-null  object
#  3   schedule_playoff     14073 non-null  bool
#  4   team_home            14073 non-null  object
#  5   score_home           13801 non-null  float64
#  6   score_away           13801 non-null  float64
#  7   team_away            14073 non-null  object
#  8   team_favorite_id     11322 non-null  object
#  9   spread_favorite      11322 non-null  float64
#  10  over_under_line      11312 non-null  object
#  11  stadium              14073 non-null  object
#  12  stadium_neutral      14073 non-null  bool
#  13  weather_temperature  12525 non-null  float64
#  14  weather_wind_mph     12509 non-null  float64
#  15  weather_humidity     8476 non-null   float64
#  16  weather_detail       3127 non-null   object
# dtypes: bool(2), float64(6), int64(1), object(8)
# memory usage: 1.6+ MB

# %% [markdown]
# * It's worth noting here that there is missing data.  A lot of weather details and scores are missing comared to the sheer size of the data set. Given the size of our data set, we will be removing columns and eliminated rows where scores are not present

# %%
#get descriptive statistics
df.describe()
# Out:
#        schedule_season    score_home    score_away  spread_favorite  \
# count     14073.000000  13801.000000  13801.000000     11322.000000
# mean       1997.167626     22.479965     19.797768        -5.372946
# std          16.699765     10.523516     10.152570         3.438739
# min        1966.000000      0.000000      0.000000       -26.500000
# 25%        1983.000000     15.000000     13.000000        -7.000000
# 50%        1998.000000     22.000000     20.000000        -4.500000
# 75%        2012.000000     29.000000     27.000000        -3.000000
# max        2024.000000     72.000000     62.000000         0.000000
#
#        weather_temperature  weather_wind_mph  weather_humidity
# count         12525.000000      12509.000000       8476.000000
# mean             59.038643          7.562475         67.212246
# std              15.516842          5.731538         15.795938
# min              -6.000000          0.000000          4.000000
# 25%              48.000000          1.000000         57.000000
# 50%              62.000000          8.000000         69.000000
# 75%              72.000000         11.000000         79.000000
# max              97.000000         40.000000        100.000000

# %%
#Using datetime function to convert the date columns from objects to date types
df['schedule_date']= pd.to_datetime(df['schedule_date'])
df['schedule_season']= pd.to_datetime(df['schedule_season'])

# %%
#verifying change has been done
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14073 entries, 0 to 14072
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   schedule_date        14073 non-null  datetime64[ns]
#  1   schedule_season      14073 non-null  datetime64[ns]
#  2   schedule_week        14073 non-null  object
#  3   schedule_playoff     14073 non-null  bool
#  4   team_home            14073 non-null  object
#  5   score_home           13801 non-null  float64
#  6   score_away           13801 non-null  float64
#  7   team_away            14073 non-null  object
#  8   team_favorite_id     11322 non-null  object
#  9   spread_favorite      11322 non-null  float64
#  10  over_under_line      11312 non-null  object
#  11  stadium              14073 non-null  object
#  12  stadium_neutral      14073 non-null  bool
#  13  weather_temperature  12525 non-null  float64
#  14  weather_wind_mph     12509 non-null  float64
#  15  weather_humidity     8476 non-null   float64
#  16  weather_detail       3127 non-null   object
# dtypes: bool(2), datetime64[ns](2), float64(6), object(7)
# memory usage: 1.6+ MB

# %%
#finding out how many rows are missing scores 
df.isnull().sum()
# Out:
# schedule_date              0
# schedule_season            0
# schedule_week              0
# schedule_playoff           0
# team_home                  0
# score_home               272
# score_away               272
# team_away                  0
# team_favorite_id        2751
# spread_favorite         2751
# over_under_line         2761
# stadium                    0
# stadium_neutral            0
# weather_temperature     1548
# weather_wind_mph        1564
# weather_humidity        5597
# weather_detail         10946
# dtype: int64

# %%
'''
Creating BOOLEAN mask in two steps: 
1. Filling in NaN values with -1, as no nfl game could have a negative score
2. Creating mask 
'''
df[['score_home','score_away']] = df[['score_home','score_away']].fillna(-1)
mask = (df['score_home'] > -1) |  (df['score_away'] > -1)

# %%
# Applying booling mask to DF
df = df[mask]

# %%
#Verifying new size
df.shape
# Out:
# (13801, 17)

# %%
#checking first/last five since all the NaN's we're at the bottom of the raw data set
df.head(-5)
# Out:
#       schedule_date               schedule_season schedule_week  \
# 0        1966-09-02 1970-01-01 00:00:00.000001966             1
# 1        1966-09-03 1970-01-01 00:00:00.000001966             1
# 2        1966-09-04 1970-01-01 00:00:00.000001966             1
# 3        1966-09-09 1970-01-01 00:00:00.000001966             2
# 4        1966-09-10 1970-01-01 00:00:00.000001966             1
# ...             ...                           ...           ...
# 13791    2024-01-14 1970-01-01 00:00:00.000002023      Wildcard
# 13792    2024-01-15 1970-01-01 00:00:00.000002023      Wildcard
# 13793    2024-01-15 1970-01-01 00:00:00.000002023      Wildcard
# 13794    2024-01-20 1970-01-01 00:00:00.000002023      Division
# 13795    2024-01-20 1970-01-01 00:00:00.000002023      Division
#
#        schedule_playoff             team_home  score_home  score_away  \
# 0                 False        Miami Dolphins        14.0        23.0
# 1                 False        Houston Oilers        45.0         7.0
# 2                 False    San Diego Chargers        27.0         7.0
# 3                 False        Miami Dolphins        14.0        19.0
# 4                 False     Green Bay Packers        24.0         3.0
# ...                 ...                   ...         ...         ...
# 13791              True         Detroit Lions        24.0        23.0
# 13792              True         Buffalo Bills        31.0        17.0
# 13793              True  Tampa Bay Buccaneers        32.0         9.0
# 13794              True      Baltimore Ravens        34.0        10.0
# 13795              True   San Francisco 49ers        24.0        21.0
#
#                  team_away team_favorite_id  spread_favorite over_under_line  \
# 0          Oakland Raiders              NaN              NaN             NaN
# 1           Denver Broncos              NaN              NaN             NaN
# 2            Buffalo Bills              NaN              NaN             NaN
# 3            New York Jets              NaN              NaN             NaN
# 4          Baltimore Colts              NaN              NaN             NaN
# ...                    ...              ...              ...             ...
# 13791     Los Angeles Rams              DET             -3.0              53
# 13792  Pittsburgh Steelers              BUF             -9.0              33
# 13793  Philadelphia Eagles              PHI             -3.0              43
# 13794       Houston Texans              BAL            -10.0              44
# 13795    Green Bay Packers               SF            -10.0            50.5
#
#                      stadium  stadium_neutral  weather_temperature  \
# 0                Orange Bowl            False                 83.0
# 1               Rice Stadium            False                 81.0
# 2             Balboa Stadium            False                 70.0
# 3                Orange Bowl            False                 82.0
# 4              Lambeau Field            False                 64.0
# ...                      ...              ...                  ...
# 13791             Ford Field            False                 72.0
# 13792       Highmark Stadium            False                 17.0
# 13793  Raymond James Stadium            False                 65.0
# 13794       M&T Bank Stadium            False                 27.0
# 13795         Levi's Stadium            False                 59.0
#
#        weather_wind_mph  weather_humidity weather_detail
# 0                   6.0              71.0            NaN
# 1                   7.0              70.0            NaN
# 2                   7.0              82.0            NaN
# 3                  11.0              78.0            NaN
# 4                   8.0              62.0            NaN
# ...                 ...               ...            ...
# 13791               0.0               NaN         indoor
# 13792              10.0              57.0            NaN
# 13793               2.0              90.0            NaN
# 13794              16.0              40.0            NaN
# 13795               8.0              77.0            NaN
#
# [13796 rows x 17 columns]

# %%
'''Verifiying only 272 rows were removed: raw data had 14073 rows including NaN in scores.
Only 272 rows should have been removed equaling the 13801 rows in the new dataframe 
'''
14073-13801
# Out:
# 272

# %% [markdown]
# The ultimate goal of this analysis is to use to historical record to predict wins the record of the team in the following season. The most recent NFL franchise to be added to the league was the Houston Texans in 2002. We will keep all data from that year onward for our analysis. In the following section we will:
# * Remove unnecessary columns
# * Add columns to determine victors
# * Group Data for visualizations

# %%
'''
using loc[] method to locate all games that took place after 9/2002 as the
start of that year's regular season was 2002/9/5
'''
df = df.loc[df['schedule_date'] >= '2002-09-01']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5929 entries, 7872 to 13800
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   schedule_date        5929 non-null   datetime64[ns]
#  1   schedule_season      5929 non-null   datetime64[ns]
#  2   schedule_week        5929 non-null   object
#  3   schedule_playoff     5929 non-null   bool
#  4   team_home            5929 non-null   object
#  5   score_home           5929 non-null   float64
#  6   score_away           5929 non-null   float64
#  7   team_away            5929 non-null   object
#  8   team_favorite_id     5929 non-null   object
#  9   spread_favorite      5929 non-null   float64
#  10  over_under_line      5929 non-null   object
#  11  stadium              5929 non-null   object
#  12  stadium_neutral      5929 non-null   bool
#  13  weather_temperature  4975 non-null   float64
#  14  weather_wind_mph     4969 non-null   float64
#  15  weather_humidity     2319 non-null   float64
#  16  weather_detail       1747 non-null   object
# dtypes: bool(2), datetime64[ns](2), float64(6), object(7)
# memory usage: 752.7+ KB

# %%
df.head()
# Out:
#      schedule_date               schedule_season schedule_week  \
# 7872    2002-09-05 1970-01-01 00:00:00.000002002             1
# 7873    2002-09-08 1970-01-01 00:00:00.000002002             1
# 7874    2002-09-08 1970-01-01 00:00:00.000002002             1
# 7875    2002-09-08 1970-01-01 00:00:00.000002002             1
# 7876    2002-09-08 1970-01-01 00:00:00.000002002             1
#
#       schedule_playoff           team_home  score_home  score_away  \
# 7872             False     New York Giants        13.0        16.0
# 7873             False       Buffalo Bills        31.0        37.0
# 7874             False   Carolina Panthers        10.0         7.0
# 7875             False       Chicago Bears        27.0        23.0
# 7876             False  Cincinnati Bengals         6.0        34.0
#
#                 team_away team_favorite_id  spread_favorite over_under_line  \
# 7872  San Francisco 49ers               SF             -4.0              39
# 7873        New York Jets              NYJ             -3.0              43
# 7874     Baltimore Ravens             PICK              0.0              33
# 7875    Minnesota Vikings              CHI             -4.5              41
# 7876   San Diego Chargers              CIN             -3.0              37
#
#                            stadium  stadium_neutral  weather_temperature  \
# 7872                Giants Stadium            False                 75.0
# 7873          Ralph Wilson Stadium            False                 75.0
# 7874       Bank of America Stadium            False                 73.0
# 7875  Memorial Stadium (Champaign)            False                 76.0
# 7876            Paul Brown Stadium            False                 81.0
#
#       weather_wind_mph  weather_humidity weather_detail
# 7872              12.0              58.0            NaN
# 7873               7.0              50.0            NaN
# 7874               8.0              66.0            NaN
# 7875               5.0              75.0            NaN
# 7876               5.0              50.0            NaN

# %%
df = df[['schedule_date','team_home','score_home','score_away','team_away','team_favorite_id','spread_favorite','over_under_line']]
df
# Out:
#       schedule_date            team_home  score_home  score_away  \
# 7872     2002-09-05      New York Giants        13.0        16.0
# 7873     2002-09-08        Buffalo Bills        31.0        37.0
# 7874     2002-09-08    Carolina Panthers        10.0         7.0
# 7875     2002-09-08        Chicago Bears        27.0        23.0
# 7876     2002-09-08   Cincinnati Bengals         6.0        34.0
# ...             ...                  ...         ...         ...
# 13796    2024-01-21        Buffalo Bills        24.0        27.0
# 13797    2024-01-21        Detroit Lions        31.0        23.0
# 13798    2024-01-28     Baltimore Ravens        10.0        17.0
# 13799    2024-01-28  San Francisco 49ers        34.0        31.0
# 13800    2024-02-11   Kansas City Chiefs        25.0        22.0
#
#                   team_away team_favorite_id  spread_favorite over_under_line
# 7872    San Francisco 49ers               SF             -4.0              39
# 7873          New York Jets              NYJ             -3.0              43
# 7874       Baltimore Ravens             PICK              0.0              33
# 7875      Minnesota Vikings              CHI             -4.5              41
# 7876     San Diego Chargers              CIN             -3.0              37
# ...                     ...              ...              ...             ...
# 13796    Kansas City Chiefs              BUF             -2.5              46
# 13797  Tampa Bay Buccaneers              DET             -6.0            49.5
# 13798    Kansas City Chiefs              BAL             -4.5              44
# 13799         Detroit Lions               SF             -7.5            53.5
# 13800   San Francisco 49ers               SF             -2.0              47
#
# [5929 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5929 entries, 7872 to 13800
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   schedule_date     5929 non-null   datetime64[ns]
#  1   team_home         5929 non-null   object
#  2   score_home        5929 non-null   float64
#  3   score_away        5929 non-null   float64
#  4   team_away         5929 non-null   object
#  5   team_favorite_id  5929 non-null   object
#  6   spread_favorite   5929 non-null   float64
#  7   over_under_line   5929 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 416.9+ KB

# %%
df['home_team_differental'] = (df['score_home'] - df['score_away'])

df['home_team_win']= np.where(df['home_team_differental']>0,True,False)

df['away_team_win']= np.where(df['home_team_differental']<0,True,False)


df.head()
# Out:
#      schedule_date           team_home  score_home  score_away  \
# 7872    2002-09-05     New York Giants        13.0        16.0
# 7873    2002-09-08       Buffalo Bills        31.0        37.0
# 7874    2002-09-08   Carolina Panthers        10.0         7.0
# 7875    2002-09-08       Chicago Bears        27.0        23.0
# 7876    2002-09-08  Cincinnati Bengals         6.0        34.0
#
#                 team_away team_favorite_id  spread_favorite over_under_line  \
# 7872  San Francisco 49ers               SF             -4.0              39
# 7873        New York Jets              NYJ             -3.0              43
# 7874     Baltimore Ravens             PICK              0.0              33
# 7875    Minnesota Vikings              CHI             -4.5              41
# 7876   San Diego Chargers              CIN             -3.0              37
#
#       home_team_differental  home_team_win  away_team_win
# 7872                   -3.0          False           True
# 7873                   -6.0          False           True
# 7874                    3.0           True          False
# 7875                    4.0           True          False
# 7876                  -28.0          False           True

# %%
df['home_team_win'].value_counts()
# Out:
# True     3345
# False    2584
# Name: home_team_win, dtype: int64

# %%
#Home wins for each team
home_wins = df.groupby(['team_home'],as_index =True).sum(['home_team_win'])
home_wins
# Out:
#                           score_home  score_away  spread_favorite  \
# team_home
# Arizona Cardinals             4085.0      4111.0           -914.0
# Atlanta Falcons               4541.0      4120.0           -909.0
# Baltimore Ravens              4614.0      3229.0          -1124.5
# Buffalo Bills                 4282.0      3736.0           -976.0
# Carolina Panthers             3863.0      3767.0           -875.5
# Chicago Bears                 4008.0      3738.0           -838.0
# Cincinnati Bengals            4210.0      4067.0           -923.0
# Cleveland Browns              3347.0      3737.0           -835.0
# Dallas Cowboys                4865.0      4052.0          -1089.0
# Denver Broncos                4453.0      3924.0          -1102.5
# Detroit Lions                 4217.0      4378.0           -900.5
# Green Bay Packers             5093.0      3749.0          -1229.5
# Houston Texans                4124.0      4098.0           -983.0
# Indianapolis Colts            4837.0      3910.0          -1143.0
# Jacksonville Jaguars          3605.0      3765.0           -907.0
# Kansas City Chiefs            4895.0      3962.0          -1164.0
# Las Vegas Raiders              850.0       827.0           -127.0
# Los Angeles Chargers          1379.0      1323.0           -307.5
# Los Angeles Rams              1659.0      1479.0           -399.5
# Miami Dolphins                3901.0      3794.0           -876.0
# Minnesota Vikings             4426.0      3809.0           -871.0
# New England Patriots          5574.0      3699.0          -1580.5
# New Orleans Saints            5096.0      4259.0          -1026.0
# New York Giants               3875.0      3965.0           -869.5
# New York Jets                 3752.0      3715.0           -876.0
# Oakland Raiders               3065.0      3618.0           -723.0
# Philadelphia Eagles           4787.0      3896.0          -1119.0
# Pittsburgh Steelers           4805.0      3652.0          -1061.0
# San Diego Chargers            3235.0      2561.0           -774.5
# San Francisco 49ers           4357.0      3864.0          -1089.0
# Seattle Seahawks              4832.0      3692.0          -1191.0
# St. Louis Rams                2444.0      2617.0           -647.5
# Tampa Bay Buccaneers          3950.0      3882.0           -828.5
# Tennessee Titans              4138.0      3989.0           -811.5
# Washington Commanders          288.0       443.0           -104.5
# Washington Football Team       333.0       378.0            -83.5
# Washington Redskins           2958.0      3289.0           -599.5
#
#                           home_team_differental  home_team_win  away_team_win
# team_home
# Arizona Cardinals                         -26.0             93             87
# Atlanta Falcons                           421.0            103             81
# Baltimore Ravens                         1385.0            130             56
# Buffalo Bills                             546.0            107             78
# Carolina Panthers                          96.0             96             87
# Chicago Bears                             270.0             95             88
# Cincinnati Bengals                        143.0            100             81
# Cleveland Browns                         -390.0             78             99
# Dallas Cowboys                            813.0            112             72
# Denver Broncos                            529.0            115             74
# Detroit Lions                            -161.0             81             98
# Green Bay Packers                        1344.0            134             56
# Houston Texans                             26.0             92             92
# Indianapolis Colts                        927.0            125             66
# Jacksonville Jaguars                     -160.0             84             96
# Kansas City Chiefs                        933.0            124             72
# Las Vegas Raiders                          23.0             17             17
# Los Angeles Chargers                       56.0             28             30
# Los Angeles Rams                          180.0             40             30
# Miami Dolphins                            107.0             97             82
# Minnesota Vikings                         617.0            114             68
# New England Patriots                     1875.0            155             50
# New Orleans Saints                        837.0            112             74
# New York Giants                           -90.0             88             92
# New York Jets                              37.0             88             91
# Oakland Raiders                          -553.0             63             84
# Philadelphia Eagles                       891.0            116             76
# Pittsburgh Steelers                      1153.0            132             57
# San Diego Chargers                        674.0             76             49
# San Francisco 49ers                       493.0            105             82
# Seattle Seahawks                         1140.0            129             61
# St. Louis Rams                           -173.0             52             61
# Tampa Bay Buccaneers                       68.0             90             95
# Tennessee Titans                          149.0             98             84
# Washington Commanders                    -155.0              5             12
# Washington Football Team                  -45.0              6             11
# Washington Redskins                      -331.0             65             81

# %%
home_wins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, Arizona Cardinals to Washington Redskins
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   score_home             37 non-null     float64
#  1   score_away             37 non-null     float64
#  2   spread_favorite        37 non-null     float64
#  3   home_team_differental  37 non-null     float64
#  4   home_team_win          37 non-null     int64
#  5   away_team_win          37 non-null     int64
# dtypes: float64(4), int64(2)
# memory usage: 2.0+ KB

# %%
#away wins for each team
away_wins = df.groupby(['team_away'],as_index=True).sum(['away_team_win'])
away_wins
# Out:
#                           score_home  score_away  spread_favorite  \
# team_away
# Arizona Cardinals             4617.0      3625.0          -1136.5
# Atlanta Falcons               4335.0      3882.0           -864.5
# Baltimore Ravens              3938.0      4120.0           -909.5
# Buffalo Bills                 4143.0      3658.0          -1001.5
# Carolina Panthers             4339.0      3923.0           -973.5
# Chicago Bears                 4166.0      3461.0          -1033.0
# Cincinnati Bengals            4185.0      3813.0           -953.5
# Cleveland Browns              4561.0      3370.0          -1129.0
# Dallas Cowboys                4007.0      3929.0           -862.5
# Denver Broncos                4239.0      3833.0           -880.5
# Detroit Lions                 4751.0      3549.0          -1074.0
# Green Bay Packers             4673.0      4731.0           -868.0
# Houston Texans                4424.0      3463.0          -1155.0
# Indianapolis Colts            4563.0      4444.0          -1005.5
# Jacksonville Jaguars          4521.0      3518.0          -1075.0
# Kansas City Chiefs            4395.0      4417.0          -1021.0
# Las Vegas Raiders              865.0       704.0           -171.0
# Los Angeles Chargers          1379.0      1417.0           -254.5
# Los Angeles Rams              1656.0      1757.0           -354.5
# Miami Dolphins                4244.0      3484.0          -1014.5
# Minnesota Vikings             4449.0      4003.0           -908.0
# New England Patriots          3850.0      4953.0          -1022.0
# New Orleans Saints            4258.0      4557.0           -887.0
# New York Giants               4527.0      4023.0          -1030.0
# New York Jets                 4368.0      3310.0          -1110.0
# Oakland Raiders               3691.0      2595.0           -978.5
# Philadelphia Eagles           4312.0      4513.0           -855.5
# Pittsburgh Steelers           3849.0      3945.0           -932.0
# San Diego Chargers            2890.0      2943.0           -593.5
# San Francisco 49ers           4441.0      3864.0          -1152.5
# Seattle Seahawks              4343.0      4192.0           -938.0
# St. Louis Rams                2848.0      1838.0           -740.5
# Tampa Bay Buccaneers          4243.0      3952.0          -1053.0
# Tennessee Titans              4399.0      3772.0           -959.5
# Washington Commanders          418.0       362.0            -79.5
# Washington Football Team       416.0       360.0            -90.0
# Washington Redskins           3440.0      2814.0           -812.5
#
#                           home_team_differental  home_team_win  away_team_win
# team_away
# Arizona Cardinals                         992.0            117             66
# Atlanta Falcons                           453.0            103             81
# Baltimore Ravens                         -182.0            101             92
# Buffalo Bills                             485.0            108             72
# Carolina Panthers                         416.0            106             80
# Chicago Bears                             705.0            109             71
# Cincinnati Bengals                        372.0            108             75
# Cleveland Browns                         1191.0            132             49
# Dallas Cowboys                             78.0             93             92
# Denver Broncos                            406.0            100             80
# Detroit Lions                            1202.0            127             53
# Green Bay Packers                         -58.0             93             99
# Houston Texans                            961.0            117             65
# Indianapolis Colts                        119.0             87            102
# Jacksonville Jaguars                     1003.0            127             56
# Kansas City Chiefs                        -22.0             89             96
# Las Vegas Raiders                         161.0             19             15
# Los Angeles Chargers                      -38.0             30             30
# Los Angeles Rams                         -101.0             31             41
# Miami Dolphins                            760.0            111             69
# Minnesota Vikings                         446.0            109             74
# New England Patriots                    -1103.0             67            122
# New Orleans Saints                       -299.0             86            100
# New York Giants                           504.0            104             85
# New York Jets                            1058.0            120             67
# Oakland Raiders                          1096.0            103             42
# Philadelphia Eagles                      -201.0             84            103
# Pittsburgh Steelers                       -96.0             84            105
# San Diego Chargers                        -53.0             67             58
# San Francisco 49ers                       577.0            109             80
# Seattle Seahawks                          151.0            103             89
# St. Louis Rams                           1010.0             81             32
# Tampa Bay Buccaneers                      291.0            105             79
# Tennessee Titans                          627.0            103             83
# Washington Commanders                      56.0              9              7
# Washington Football Team                   56.0              9              8
# Washington Redskins                       626.0             94             52

# %% [markdown]
# There are 32 teams in the NFL, but 37 rows in this data frame. Teams that have either been renamed or relocated are the Raiders, Commanders, Chargers and Rams. Below we will combine those team names and combine the data into one Dataframe so we can evaluate the total number of wins each franchise has had since 2002. This is the dataframe we can use for statistical analysis

# %%
#Replacing teams mentioned above using a dictionary 
home_wins = home_wins.rename(index= {'Washington Redskins':'Washington Commanders','Washington Football Team':'Washington Commanders',
                         'Oakland Raiders': 'Las Vegas Raiders','San Diego Chargers':'Los Angeles Chargers', 
                         'St. Louis Rams':'Los Angeles Rams'})

# %%
away_wins = away_wins.rename(index= {'Washington Redskins':'Washington Commanders','Washington Football Team':'Washington Commanders',
                         'Oakland Raiders': 'Las Vegas Raiders','San Diego Chargers':'Los Angeles Chargers', 
                         'St. Louis Rams':'Los Angeles Rams'})

# %%
#resetting index
home_wins = home_wins.reset_index()

# %%
#resetting index
away_wins = away_wins.reset_index()

# %% [markdown]
# # The Following Section Will Accomplish the Following:
# * Combine the repeat teams into one row, creating a 32 row dataframe (both data sets)
# * Insert new row into data frame, delete the previous rows that had repeat names (both data sets)

# %%
#start with home team Data 
home_wins.values.tolist()
# Out:
# [['Arizona Cardinals', 4085.0, 4111.0, -914.0, -26.0, 93, 87],
#  ['Atlanta Falcons', 4541.0, 4120.0, -909.0, 421.0, 103, 81],
#  ['Baltimore Ravens', 4614.0, 3229.0, -1124.5, 1385.0, 130, 56],
#  ['Buffalo Bills', 4282.0, 3736.0, -976.0, 546.0, 107, 78],
#  ['Carolina Panthers', 3863.0, 3767.0, -875.5, 96.0, 96, 87],
#  ['Chicago Bears', 4008.0, 3738.0, -838.0, 270.0, 95, 88],
#  ['Cincinnati Bengals', 4210.0, 4067.0, -923.0, 143.0, 100, 81],
#  ['Cleveland Browns', 3347.0, 3737.0, -835.0, -390.0, 78, 99],
#  ['Dallas Cowboys', 4865.0, 4052.0, -1089.0, 813.0, 112, 72],
#  ['Denver Broncos', 4453.0, 3924.0, -1102.5, 529.0, 115, 74],
#  ['Detroit Lions', 4217.0, 4378.0, -900.5, -161.0, 81, 98],
#  ['Green Bay Packers', 5093.0, 3749.0, -1229.5, 1344.0, 134, 56],
#  ['Houston Texans', 4124.0, 4098.0, -983.0, 26.0, 92, 92],
#  ['Indianapolis Colts', 4837.0, 3910.0, -1143.0, 927.0, 125, 66],
#  ['Jacksonville Jaguars', 3605.0, 3765.0, -907.0, -160.0, 84, 96],
#  ['Kansas City Chiefs', 4895.0, 3962.0, -1164.0, 933.0, 124, 72],
#  ['Las Vegas Raiders', 850.0, 827.0, -127.0, 23.0, 17, 17],
#  ['Los Angeles Chargers', 1379.0, 1323.0, -307.5, 56.0, 28, 30],
#  ['Los Angeles Rams', 1659.0, 1479.0, -399.5, 180.0, 40, 30],
#  ['Miami Dolphins', 3901.0, 3794.0, -876.0, 107.0, 97, 82],
#  ['Minnesota Vikings', 4426.0, 3809.0, -871.0, 617.0, 114, 68],
#  ['New England Patriots', 5574.0, 3699.0, -1580.5, 1875.0, 155, 50],
#  ['New Orleans Saints', 5096.0, 4259.0, -1026.0, 837.0, 112, 74],
#  ['New York Giants', 3875.0, 3965.0, -869.5, -90.0, 88, 92],
#  ['New York Jets', 3752.0, 3715.0, -876.0, 37.0, 88, 91],
#  ['Las Vegas Raiders', 3065.0, 3618.0, -723.0, -553.0, 63, 84],
#  ['Philadelphia Eagles', 4787.0, 3896.0, -1119.0, 891.0, 116, 76],
#  ['Pittsburgh Steelers', 4805.0, 3652.0, -1061.0, 1153.0, 132, 57],
#  ['Los Angeles Chargers', 3235.0, 2561.0, -774.5, 674.0, 76, 49],
#  ['San Francisco 49ers', 4357.0, 3864.0, -1089.0, 493.0, 105, 82],
#  ['Seattle Seahawks', 4832.0, 3692.0, -1191.0, 1140.0, 129, 61],
#  ['Los Angeles Rams', 2444.0, 2617.0, -647.5, -173.0, 52, 61],
#  ['Tampa Bay Buccaneers', 3950.0, 3882.0, -828.5, 68.0, 90, 95],
#  ['Tennessee Titans', 4138.0, 3989.0, -811.5, 149.0, 98, 84],
#  ['Washington Commanders', 288.0, 443.0, -104.5, -155.0, 5, 12],
#  ['Washington Commanders', 333.0, 378.0, -83.5, -45.0, 6, 11],
#  ['Washington Commanders', 2958.0, 3289.0, -599.5, -331.0, 65, 81]]

# %%
'''
creating lists for all commanders teams
converting lists to arrays
adding rays together
print result
'''
homeramslist1 = [2444.0, 2617.0, -647.5, -173.0, 52, 61]
homeramslist2 = [1659.0, 1479.0, -399.5, 180.0, 40, 30]

homerams_array1 =  np.asarray(homeramslist1)
homerams_array2 =   np.asarray(homeramslist2)

home_rams_array = homerams_array1 + homerams_array2
print(home_rams_array)
# Out:
# [ 4103.  4096. -1047.     7.    92.    91.]

# %%
'''
creating lists for all commanders teams
converting lists to arrays
adding rays together
print result
'''
commlist1 = [288.0, 443.0, -104.5, -155.0, 5, 12]
commlist2 = [333.0, 378.0, -83.5, -45.0, 6, 11]
commlist3= [2958.0, 3289.0, -599.5, -331.0, 65, 81]

comm_array1 =  np.asarray(commlist1)
comm_array2 =   np.asarray(commlist2)    
comm_array3 = np.asarray(commlist3)

home_comm_array = comm_array1 + comm_array2 +comm_array3
print(home_comm_array)
# Out:
# [3579.  4110.  -787.5 -531.    76.   104. ]

# %%
'''
creating lists for all commanders teams
converting lists to arrays
adding rays together
print result
'''
homechargerlist1 = [3235.0, 2561.0, -774.5, 674.0, 76, 49]
homechargerlist2 = [1379.0, 1323.0, -307.5, 56.0, 28, 30]

homecharger_array1 =  np.asarray(homechargerlist1)
homecharger_array2 =   np.asarray(homechargerlist2)

home_charger_array = homecharger_array1 + homecharger_array2
print(home_charger_array)
# Out:
# [ 4614.  3884. -1082.   730.   104.    79.]

# %%
'''
creating lists for all commanders teams
converting lists to arrays
adding rays together
print result
'''

raiderslist1 = [3065.0, 3618.0, -723.0, -553.0, 63, 84]
raiderslist2 = [850.0, 827.0, -127.0, 23.0, 17, 17]

raidersarray1 =  np.asarray(raiderslist1)
raidersarray2 =   np.asarray(raiderslist2) 

home_raider_array = raidersarray1 + raidersarray2
print(home_raider_array)
# Out:
# [3915. 4445. -850. -530.   80.  101.]

# %%
#away dataset
away_wins.values.tolist()
# Out:
# [['Arizona Cardinals', 4617.0, 3625.0, -1136.5, 992.0, 117, 66],
#  ['Atlanta Falcons', 4335.0, 3882.0, -864.5, 453.0, 103, 81],
#  ['Baltimore Ravens', 3938.0, 4120.0, -909.5, -182.0, 101, 92],
#  ['Buffalo Bills', 4143.0, 3658.0, -1001.5, 485.0, 108, 72],
#  ['Carolina Panthers', 4339.0, 3923.0, -973.5, 416.0, 106, 80],
#  ['Chicago Bears', 4166.0, 3461.0, -1033.0, 705.0, 109, 71],
#  ['Cincinnati Bengals', 4185.0, 3813.0, -953.5, 372.0, 108, 75],
#  ['Cleveland Browns', 4561.0, 3370.0, -1129.0, 1191.0, 132, 49],
#  ['Dallas Cowboys', 4007.0, 3929.0, -862.5, 78.0, 93, 92],
#  ['Denver Broncos', 4239.0, 3833.0, -880.5, 406.0, 100, 80],
#  ['Detroit Lions', 4751.0, 3549.0, -1074.0, 1202.0, 127, 53],
#  ['Green Bay Packers', 4673.0, 4731.0, -868.0, -58.0, 93, 99],
#  ['Houston Texans', 4424.0, 3463.0, -1155.0, 961.0, 117, 65],
#  ['Indianapolis Colts', 4563.0, 4444.0, -1005.5, 119.0, 87, 102],
#  ['Jacksonville Jaguars', 4521.0, 3518.0, -1075.0, 1003.0, 127, 56],
#  ['Kansas City Chiefs', 4395.0, 4417.0, -1021.0, -22.0, 89, 96],
#  ['Las Vegas Raiders', 865.0, 704.0, -171.0, 161.0, 19, 15],
#  ['Los Angeles Chargers', 1379.0, 1417.0, -254.5, -38.0, 30, 30],
#  ['Los Angeles Rams', 1656.0, 1757.0, -354.5, -101.0, 31, 41],
#  ['Miami Dolphins', 4244.0, 3484.0, -1014.5, 760.0, 111, 69],
#  ['Minnesota Vikings', 4449.0, 4003.0, -908.0, 446.0, 109, 74],
#  ['New England Patriots', 3850.0, 4953.0, -1022.0, -1103.0, 67, 122],
#  ['New Orleans Saints', 4258.0, 4557.0, -887.0, -299.0, 86, 100],
#  ['New York Giants', 4527.0, 4023.0, -1030.0, 504.0, 104, 85],
#  ['New York Jets', 4368.0, 3310.0, -1110.0, 1058.0, 120, 67],
#  ['Las Vegas Raiders', 3691.0, 2595.0, -978.5, 1096.0, 103, 42],
#  ['Philadelphia Eagles', 4312.0, 4513.0, -855.5, -201.0, 84, 103],
#  ['Pittsburgh Steelers', 3849.0, 3945.0, -932.0, -96.0, 84, 105],
#  ['Los Angeles Chargers', 2890.0, 2943.0, -593.5, -53.0, 67, 58],
#  ['San Francisco 49ers', 4441.0, 3864.0, -1152.5, 577.0, 109, 80],
#  ['Seattle Seahawks', 4343.0, 4192.0, -938.0, 151.0, 103, 89],
#  ['Los Angeles Rams', 2848.0, 1838.0, -740.5, 1010.0, 81, 32],
#  ['Tampa Bay Buccaneers', 4243.0, 3952.0, -1053.0, 291.0, 105, 79],
#  ['Tennessee Titans', 4399.0, 3772.0, -959.5, 627.0, 103, 83],
#  ['Washington Commanders', 418.0, 362.0, -79.5, 56.0, 9, 7],
#  ['Washington Commanders', 416.0, 360.0, -90.0, 56.0, 9, 8],
#  ['Washington Commanders', 3440.0, 2814.0, -812.5, 626.0, 94, 52]]

# %%
'''
creating lists for all commanders teams
converting lists to arrays
adding rays together
print result
'''
away_ramslist1 = [1656.0, 1757.0, -354.5, -101.0, 31, 41]
away_ramslist2 = [2848.0, 1838.0, -740.5, 1010.0, 81, 32]

away_rams_array1 =  np.asarray(away_ramslist1)
away_rams_array2 =   np.asarray(away_ramslist2)

away_rams_array = away_rams_array1 + away_rams_array2
print(away_rams_array)
# Out:
# [ 4504.  3595. -1095.   909.   112.    73.]

# %%
'''
creating lists for all commanders teams
converting lists to arrays
adding rays together
print result
'''
commlist1 = [418.0, 362.0, -79.5, 56.0, 9, 7]
commlist2 = [416.0, 360.0, -90.0, 56.0, 9, 8]
commlist3= [3440.0, 2814.0, -812.5, 626.0, 94, 52]

comm_array1 =  np.asarray(commlist1)
comm_array2 =   np.asarray(commlist2)    
comm_array3 = np.asarray(commlist3)

away_comm_array = comm_array1 + comm_array2 +comm_array3
print(away_comm_array)
# Out:
# [4274. 3536. -982.  738.  112.   67.]

# %%
'''
creating lists for all commanders teams
converting lists to arrays
adding rays together
print result
'''
chargerlist1 = [2890.0, 2943.0, -593.5, -53.0, 67, 58]

chargerlist2 = [1379.0, 1417.0, -254.5, -38.0, 30, 30]

charger_array1 =  np.asarray(chargerlist1)
charger_array2 =   np.asarray(chargerlist2)

away_charger_array = charger_array1 + charger_array2
print(away_charger_array)
# Out:
# [4269. 4360. -848.  -91.   97.   88.]

# %%
'''
creating lists for all commanders teams
converting lists to arrays
adding rays together
print result
'''

raiderslist1 = [865.0, 704.0, -171.0, 161.0, 19, 15]
raiderslist2 = [3691.0, 2595.0, -978.5, 1096.0, 103, 42]

raidersarray1 =  np.asarray(raiderslist1)
raidersarray2 =   np.asarray(raiderslist2) 

away_raider_array = raidersarray1 + raidersarray2
print(away_raider_array)
# Out:
# [ 4556.   3299.  -1149.5  1257.    122.     57. ]

# %%
'''
Add team names to away team arrays 
'''
away_rams_array = np.append('Los Angeles Rams',away_rams_array)
print(away_rams_array)

away_raider_array = np.append('Las Vegas Raiders',away_raider_array)
print(away_raider_array)

away_charger_array = np.append('Los Angeles Chargers',away_charger_array)
print(away_charger_array)

away_comm_array = np.append('Washington Commanders',away_comm_array)
print(away_comm_array)
# Out:
# ['Los Angeles Rams' '4504.0' '3595.0' '-1095.0' '909.0' '112.0' '73.0']
# ['Las Vegas Raiders' '4556.0' '3299.0' '-1149.5' '1257.0' '122.0' '57.0']
# ['Los Angeles Chargers' '4269.0' '4360.0' '-848.0' '-91.0' '97.0' '88.0']
# ['Washington Commanders' '4274.0' '3536.0' '-982.0' '738.0' '112.0' '67.0']

# %%
'''
Add team names to home team arrays 
'''
home_rams_array = np.append('Los Angeles Rams',home_rams_array)
print(home_rams_array)

home_raider_array = np.append('Las Vegas Raiders',home_raider_array)
print(home_raider_array)

home_charger_array = np.append('Los Angeles Chargers',home_charger_array)
print(away_charger_array)

home_comm_array = np.append('Washington Commanders',home_comm_array)
print(home_comm_array)
# Out:
# ['Los Angeles Rams' '4103.0' '4096.0' '-1047.0' '7.0' '92.0' '91.0']
# ['Las Vegas Raiders' '3915.0' '4445.0' '-850.0' '-530.0' '80.0' '101.0']
# ['Los Angeles Chargers' '4269.0' '4360.0' '-848.0' '-91.0' '97.0' '88.0']
# ['Washington Commanders' '3579.0' '4110.0' '-787.5' '-531.0' '76.0'
#  '104.0']

# %%
away_wins
# Out:
#                 team_away  score_home  score_away  spread_favorite  \
# 0       Arizona Cardinals      4617.0      3625.0          -1136.5
# 1         Atlanta Falcons      4335.0      3882.0           -864.5
# 2        Baltimore Ravens      3938.0      4120.0           -909.5
# 3           Buffalo Bills      4143.0      3658.0          -1001.5
# 4       Carolina Panthers      4339.0      3923.0           -973.5
# 5           Chicago Bears      4166.0      3461.0          -1033.0
# 6      Cincinnati Bengals      4185.0      3813.0           -953.5
# 7        Cleveland Browns      4561.0      3370.0          -1129.0
# 8          Dallas Cowboys      4007.0      3929.0           -862.5
# 9          Denver Broncos      4239.0      3833.0           -880.5
# 10          Detroit Lions      4751.0      3549.0          -1074.0
# 11      Green Bay Packers      4673.0      4731.0           -868.0
# 12         Houston Texans      4424.0      3463.0          -1155.0
# 13     Indianapolis Colts      4563.0      4444.0          -1005.5
# 14   Jacksonville Jaguars      4521.0      3518.0          -1075.0
# 15     Kansas City Chiefs      4395.0      4417.0          -1021.0
# 16      Las Vegas Raiders       865.0       704.0           -171.0
# 17   Los Angeles Chargers      1379.0      1417.0           -254.5
# 18       Los Angeles Rams      1656.0      1757.0           -354.5
# 19         Miami Dolphins      4244.0      3484.0          -1014.5
# 20      Minnesota Vikings      4449.0      4003.0           -908.0
# 21   New England Patriots      3850.0      4953.0          -1022.0
# 22     New Orleans Saints      4258.0      4557.0           -887.0
# 23        New York Giants      4527.0      4023.0          -1030.0
# 24          New York Jets      4368.0      3310.0          -1110.0
# 25      Las Vegas Raiders      3691.0      2595.0           -978.5
# 26    Philadelphia Eagles      4312.0      4513.0           -855.5
# 27    Pittsburgh Steelers      3849.0      3945.0           -932.0
# 28   Los Angeles Chargers      2890.0      2943.0           -593.5
# 29    San Francisco 49ers      4441.0      3864.0          -1152.5
# 30       Seattle Seahawks      4343.0      4192.0           -938.0
# 31       Los Angeles Rams      2848.0      1838.0           -740.5
# 32   Tampa Bay Buccaneers      4243.0      3952.0          -1053.0
# 33       Tennessee Titans      4399.0      3772.0           -959.5
# 34  Washington Commanders       418.0       362.0            -79.5
# 35  Washington Commanders       416.0       360.0            -90.0
# 36  Washington Commanders      3440.0      2814.0           -812.5
#
#     home_team_differental  home_team_win  away_team_win
# 0                   992.0            117             66
# 1                   453.0            103             81
# 2                  -182.0            101             92
# 3                   485.0            108             72
# 4                   416.0            106             80
# 5                   705.0            109             71
# 6                   372.0            108             75
# 7                  1191.0            132             49
# 8                    78.0             93             92
# 9                   406.0            100             80
# 10                 1202.0            127             53
# 11                  -58.0             93             99
# 12                  961.0            117             65
# 13                  119.0             87            102
# 14                 1003.0            127             56
# 15                  -22.0             89             96
# 16                  161.0             19             15
# 17                  -38.0             30             30
# 18                 -101.0             31             41
# 19                  760.0            111             69
# 20                  446.0            109             74
# 21                -1103.0             67            122
# 22                 -299.0             86            100
# 23                  504.0            104             85
# 24                 1058.0            120             67
# 25                 1096.0            103             42
# 26                 -201.0             84            103
# 27                  -96.0             84            105
# 28                  -53.0             67             58
# 29                  577.0            109             80
# 30                  151.0            103             89
# 31                 1010.0             81             32
# 32                  291.0            105             79
# 33                  627.0            103             83
# 34                   56.0              9              7
# 35                   56.0              9              8
# 36                  626.0             94             52

# %%
'''
Add arrays to existing dataframs 
'''

away_wins.loc[len(away_wins)] = away_comm_array 
away_wins.loc[len(away_wins)] = away_charger_array 
away_wins.loc[len(away_wins)] = away_raider_array 
away_wins.loc[len(away_wins)] = away_rams_array 

home_wins.loc[len(home_wins)] = home_comm_array 
home_wins.loc[len(home_wins)] = home_charger_array 
home_wins.loc[len(home_wins)] = home_raider_array 
home_wins.loc[len(home_wins)] = home_rams_array

# %%
away_wins
# Out:
#                 team_away score_home score_away spread_favorite  \
# 0       Arizona Cardinals     4617.0     3625.0         -1136.5
# 1         Atlanta Falcons     4335.0     3882.0          -864.5
# 2        Baltimore Ravens     3938.0     4120.0          -909.5
# 3           Buffalo Bills     4143.0     3658.0         -1001.5
# 4       Carolina Panthers     4339.0     3923.0          -973.5
# 5           Chicago Bears     4166.0     3461.0         -1033.0
# 6      Cincinnati Bengals     4185.0     3813.0          -953.5
# 7        Cleveland Browns     4561.0     3370.0         -1129.0
# 8          Dallas Cowboys     4007.0     3929.0          -862.5
# 9          Denver Broncos     4239.0     3833.0          -880.5
# 10          Detroit Lions     4751.0     3549.0         -1074.0
# 11      Green Bay Packers     4673.0     4731.0          -868.0
# 12         Houston Texans     4424.0     3463.0         -1155.0
# 13     Indianapolis Colts     4563.0     4444.0         -1005.5
# 14   Jacksonville Jaguars     4521.0     3518.0         -1075.0
# 15     Kansas City Chiefs     4395.0     4417.0         -1021.0
# 16      Las Vegas Raiders      865.0      704.0          -171.0
# 17   Los Angeles Chargers     1379.0     1417.0          -254.5
# 18       Los Angeles Rams     1656.0     1757.0          -354.5
# 19         Miami Dolphins     4244.0     3484.0         -1014.5
# 20      Minnesota Vikings     4449.0     4003.0          -908.0
# 21   New England Patriots     3850.0     4953.0         -1022.0
# 22     New Orleans Saints     4258.0     4557.0          -887.0
# 23        New York Giants     4527.0     4023.0         -1030.0
# 24          New York Jets     4368.0     3310.0         -1110.0
# 25      Las Vegas Raiders     3691.0     2595.0          -978.5
# 26    Philadelphia Eagles     4312.0     4513.0          -855.5
# 27    Pittsburgh Steelers     3849.0     3945.0          -932.0
# 28   Los Angeles Chargers     2890.0     2943.0          -593.5
# 29    San Francisco 49ers     4441.0     3864.0         -1152.5
# 30       Seattle Seahawks     4343.0     4192.0          -938.0
# 31       Los Angeles Rams     2848.0     1838.0          -740.5
# 32   Tampa Bay Buccaneers     4243.0     3952.0         -1053.0
# 33       Tennessee Titans     4399.0     3772.0          -959.5
# 34  Washington Commanders      418.0      362.0           -79.5
# 35  Washington Commanders      416.0      360.0           -90.0
# 36  Washington Commanders     3440.0     2814.0          -812.5
# 37  Washington Commanders     4274.0     3536.0          -982.0
# 38   Los Angeles Chargers     4269.0     4360.0          -848.0
# 39      Las Vegas Raiders     4556.0     3299.0         -1149.5
# 40       Los Angeles Rams     4504.0     3595.0         -1095.0
#
#    home_team_differental home_team_win away_team_win
# 0                  992.0           117            66
# 1                  453.0           103            81
# 2                 -182.0           101            92
# 3                  485.0           108            72
# 4                  416.0           106            80
# 5                  705.0           109            71
# 6                  372.0           108            75
# 7                 1191.0           132            49
# 8                   78.0            93            92
# 9                  406.0           100            80
# 10                1202.0           127            53
# 11                 -58.0            93            99
# 12                 961.0           117            65
# 13                 119.0            87           102
# 14                1003.0           127            56
# 15                 -22.0            89            96
# 16                 161.0            19            15
# 17                 -38.0            30            30
# 18                -101.0            31            41
# 19                 760.0           111            69
# 20                 446.0           109            74
# 21               -1103.0            67           122
# 22                -299.0            86           100
# 23                 504.0           104            85
# 24                1058.0           120            67
# 25                1096.0           103            42
# 26                -201.0            84           103
# 27                 -96.0            84           105
# 28                 -53.0            67            58
# 29                 577.0           109            80
# 30                 151.0           103            89
# 31                1010.0            81            32
# 32                 291.0           105            79
# 33                 627.0           103            83
# 34                  56.0             9             7
# 35                  56.0             9             8
# 36                 626.0            94            52
# 37                 738.0         112.0          67.0
# 38                 -91.0          97.0          88.0
# 39                1257.0         122.0          57.0
# 40                 909.0         112.0          73.0

# %%
#indexes to remove: 34-36, 31, 28,25,17,16, using drop() function

home_wins = home_wins.drop(index = [31, 28,25,17,16,34,35,36,31], )

away_wins = away_wins.drop(index = [31, 28,25,17,16,34,35,36,31] )

# %%
'''
Verifying all relevant 32 teams are present
'''
home_wins=home_wins.reset_index()
home_wins
# Out:
#     index              team_home score_home score_away spread_favorite  \
# 0       0      Arizona Cardinals     4085.0     4111.0          -914.0
# 1       1        Atlanta Falcons     4541.0     4120.0          -909.0
# 2       2       Baltimore Ravens     4614.0     3229.0         -1124.5
# 3       3          Buffalo Bills     4282.0     3736.0          -976.0
# 4       4      Carolina Panthers     3863.0     3767.0          -875.5
# 5       5          Chicago Bears     4008.0     3738.0          -838.0
# 6       6     Cincinnati Bengals     4210.0     4067.0          -923.0
# 7       7       Cleveland Browns     3347.0     3737.0          -835.0
# 8       8         Dallas Cowboys     4865.0     4052.0         -1089.0
# 9       9         Denver Broncos     4453.0     3924.0         -1102.5
# 10     10          Detroit Lions     4217.0     4378.0          -900.5
# 11     11      Green Bay Packers     5093.0     3749.0         -1229.5
# 12     12         Houston Texans     4124.0     4098.0          -983.0
# 13     13     Indianapolis Colts     4837.0     3910.0         -1143.0
# 14     14   Jacksonville Jaguars     3605.0     3765.0          -907.0
# 15     15     Kansas City Chiefs     4895.0     3962.0         -1164.0
# 16     18       Los Angeles Rams     1659.0     1479.0          -399.5
# 17     19         Miami Dolphins     3901.0     3794.0          -876.0
# 18     20      Minnesota Vikings     4426.0     3809.0          -871.0
# 19     21   New England Patriots     5574.0     3699.0         -1580.5
# 20     22     New Orleans Saints     5096.0     4259.0         -1026.0
# 21     23        New York Giants     3875.0     3965.0          -869.5
# 22     24          New York Jets     3752.0     3715.0          -876.0
# 23     26    Philadelphia Eagles     4787.0     3896.0         -1119.0
# 24     27    Pittsburgh Steelers     4805.0     3652.0         -1061.0
# 25     29    San Francisco 49ers     4357.0     3864.0         -1089.0
# 26     30       Seattle Seahawks     4832.0     3692.0         -1191.0
# 27     32   Tampa Bay Buccaneers     3950.0     3882.0          -828.5
# 28     33       Tennessee Titans     4138.0     3989.0          -811.5
# 29     37  Washington Commanders     3579.0     4110.0          -787.5
# 30     38   Los Angeles Chargers     4614.0     3884.0         -1082.0
# 31     39      Las Vegas Raiders     3915.0     4445.0          -850.0
# 32     40       Los Angeles Rams     4103.0     4096.0         -1047.0
#
#    home_team_differental home_team_win away_team_win
# 0                  -26.0            93            87
# 1                  421.0           103            81
# 2                 1385.0           130            56
# 3                  546.0           107            78
# 4                   96.0            96            87
# 5                  270.0            95            88
# 6                  143.0           100            81
# 7                 -390.0            78            99
# 8                  813.0           112            72
# 9                  529.0           115            74
# 10                -161.0            81            98
# 11                1344.0           134            56
# 12                  26.0            92            92
# 13                 927.0           125            66
# 14                -160.0            84            96
# 15                 933.0           124            72
# 16                 180.0            40            30
# 17                 107.0            97            82
# 18                 617.0           114            68
# 19                1875.0           155            50
# 20                 837.0           112            74
# 21                 -90.0            88            92
# 22                  37.0            88            91
# 23                 891.0           116            76
# 24                1153.0           132            57
# 25                 493.0           105            82
# 26                1140.0           129            61
# 27                  68.0            90            95
# 28                 149.0            98            84
# 29                -531.0          76.0         104.0
# 30                 730.0         104.0          79.0
# 31                -530.0          80.0         101.0
# 32                   7.0          92.0          91.0

# %%
'''
Verifying all relevant 32 teams are present
'''
away_wins = away_wins.reset_index()
away_wins
# Out:
#     index              team_away score_home score_away spread_favorite  \
# 0       0      Arizona Cardinals     4617.0     3625.0         -1136.5
# 1       1        Atlanta Falcons     4335.0     3882.0          -864.5
# 2       2       Baltimore Ravens     3938.0     4120.0          -909.5
# 3       3          Buffalo Bills     4143.0     3658.0         -1001.5
# 4       4      Carolina Panthers     4339.0     3923.0          -973.5
# 5       5          Chicago Bears     4166.0     3461.0         -1033.0
# 6       6     Cincinnati Bengals     4185.0     3813.0          -953.5
# 7       7       Cleveland Browns     4561.0     3370.0         -1129.0
# 8       8         Dallas Cowboys     4007.0     3929.0          -862.5
# 9       9         Denver Broncos     4239.0     3833.0          -880.5
# 10     10          Detroit Lions     4751.0     3549.0         -1074.0
# 11     11      Green Bay Packers     4673.0     4731.0          -868.0
# 12     12         Houston Texans     4424.0     3463.0         -1155.0
# 13     13     Indianapolis Colts     4563.0     4444.0         -1005.5
# 14     14   Jacksonville Jaguars     4521.0     3518.0         -1075.0
# 15     15     Kansas City Chiefs     4395.0     4417.0         -1021.0
# 16     18       Los Angeles Rams     1656.0     1757.0          -354.5
# 17     19         Miami Dolphins     4244.0     3484.0         -1014.5
# 18     20      Minnesota Vikings     4449.0     4003.0          -908.0
# 19     21   New England Patriots     3850.0     4953.0         -1022.0
# 20     22     New Orleans Saints     4258.0     4557.0          -887.0
# 21     23        New York Giants     4527.0     4023.0         -1030.0
# 22     24          New York Jets     4368.0     3310.0         -1110.0
# 23     26    Philadelphia Eagles     4312.0     4513.0          -855.5
# 24     27    Pittsburgh Steelers     3849.0     3945.0          -932.0
# 25     29    San Francisco 49ers     4441.0     3864.0         -1152.5
# 26     30       Seattle Seahawks     4343.0     4192.0          -938.0
# 27     32   Tampa Bay Buccaneers     4243.0     3952.0         -1053.0
# 28     33       Tennessee Titans     4399.0     3772.0          -959.5
# 29     37  Washington Commanders     4274.0     3536.0          -982.0
# 30     38   Los Angeles Chargers     4269.0     4360.0          -848.0
# 31     39      Las Vegas Raiders     4556.0     3299.0         -1149.5
# 32     40       Los Angeles Rams     4504.0     3595.0         -1095.0
#
#    home_team_differental home_team_win away_team_win
# 0                  992.0           117            66
# 1                  453.0           103            81
# 2                 -182.0           101            92
# 3                  485.0           108            72
# 4                  416.0           106            80
# 5                  705.0           109            71
# 6                  372.0           108            75
# 7                 1191.0           132            49
# 8                   78.0            93            92
# 9                  406.0           100            80
# 10                1202.0           127            53
# 11                 -58.0            93            99
# 12                 961.0           117            65
# 13                 119.0            87           102
# 14                1003.0           127            56
# 15                 -22.0            89            96
# 16                -101.0            31            41
# 17                 760.0           111            69
# 18                 446.0           109            74
# 19               -1103.0            67           122
# 20                -299.0            86           100
# 21                 504.0           104            85
# 22                1058.0           120            67
# 23                -201.0            84           103
# 24                 -96.0            84           105
# 25                 577.0           109            80
# 26                 151.0           103            89
# 27                 291.0           105            79
# 28                 627.0           103            83
# 29                 738.0         112.0          67.0
# 30                 -91.0          97.0          88.0
# 31                1257.0         122.0          57.0
# 32                 909.0         112.0          73.0

# %%
#dropping extra index column
home_wins = home_wins.drop('index', axis=1)

# %%
#dropping extra index column
away_wins = away_wins.drop('index', axis=1)

# %%
#sorting in alphabetical oder
home_wins = home_wins.sort_values(['team_home'], ascending = True)
away_wins =away_wins.sort_values(['team_away'], ascending = True)

# %% [markdown]
# # Visualizing the Datasets

# %%
#Bar chart to visualize the teams with the most home wins 2002
x = home_wins['team_home']
y = home_wins['home_team_win'].astype(float)
color = ['green']
plt.bar(x,y,color = color)
plt.title('Most Home Wins since 2002',fontsize = 30)
plt.xticks(rotation=45 , horizontalalignment = 'right',fontsize=25)
plt.yticks(fontsize = 25)

plt.ylabel('Number of Wins',fontsize=25)


plt.rcParams["figure.figsize"] = (40,15)

# %%
#Bar chart to visualize the teams with the most away wins 2002
x = away_wins['team_away']
y = away_wins['away_team_win'].astype(float)

plt.bar(x,y,color = 'green')
plt.title('Most Away Wins since 2002',fontsize = 30)
plt.xticks(rotation=45 , horizontalalignment = 'right',fontsize=25)
plt.yticks(fontsize = 25)

plt.ylabel('Number of Wins')


plt.rcParams["figure.figsize"] = (40,15)

# %%
#Bar chart to visualize the teams with the most away losses 2002
x = away_wins['team_away']
y = away_wins['home_team_win'].astype(float)

plt.bar(x,y,color='red')
plt.title('Most Away Losses since 2002',fontsize = 30)
plt.xticks(rotation=45 , horizontalalignment = 'right',fontsize=25)
plt.yticks(fontsize = 25)


plt.ylabel('Number of Losses')


plt.rcParams["figure.figsize"] = (40,15)

# %%
x = home_wins['team_home']
y = home_wins['away_team_win'].astype(float)
color = ['red', 'blue', 'orange']
plt.bar(x,y,color = color)
plt.title('Most Home Losses since 2002',fontsize = 30)
plt.xticks(rotation=45 , horizontalalignment = 'right',fontsize=25)
plt.yticks(fontsize = 25)


plt.ylabel('Number of Wins',fontsize=25)


plt.rcParams["figure.figsize"] = (40,15)
